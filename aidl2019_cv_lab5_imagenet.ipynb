# %% [markdown]
# <a href="https://colab.research.google.com/github/griu/deeplearningupc/blob/master/aidl2019_cv_lab5_imagenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from matplotlib.pyplot import imshow
if not torch.cuda.is_available():
    print("You should enable GPU runtime!!")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# %matplotlib inline

# %% [markdown]
# # First contact with PyTorch
#
# We will first train a network to classify MNIST to get familiarized with PyTorch's syntax.
#
#
# First, we define our neural network. In PyTorch,  NN are just Python classes that inherit from nn.Module. We declare all the layers that we are going to use in the constructor (init method), and then define how we should do the forward pass in the `forward` method. The `backward` method is done automatically, so we do not need to code it.

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=20, kernel_size=5, stride=1)
        self.conv2 = nn.Conv2d(in_channels=20, out_channels=50, kernel_size=5, stride=1)
        self.fc1 = nn.Linear(in_features=4*4*50, out_features=500)
        self.fc2 = nn.Linear(in_features=500, out_features=10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(x.size(0), -1)  # Flatten while keeping the batch dimension
        x = F.relu(self.fc1(x))
        x = F.log_softmax(self.fc2(x), dim=1)
        return x
   

model = Net().to(device)  # Move model to GPU

# %% [markdown]
# We now define the dataloaders that will feed the data to our NN during trainig in batches. The `dataset` class `torchvision.dataset.MNIST` already has the MNIST dataset loaded. We could add data augmentation here.

# %%
train_dataset = datasets.MNIST("data/MNIST", train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),  # Here we could add extra data augmentation
                       transforms.Normalize((0.1307,), (0.3081,)),
                   ]))
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=100, shuffle=True)

test_dataset = datasets.MNIST("data/MNIST", train=False, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,)),
                   ]))
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False)
# Out:
# 0it [00:00, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz
# 9920512it [00:01, 8816902.48it/s]
# Extracting data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz
# 32768it [00:00, 129457.39it/s]
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
# 1654784it [00:00, 2204996.39it/s]
# 0it [00:00, ?it/s]
# Extracting data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 8192it [00:00, 47545.02it/s]
# Extracting data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %% [markdown]
# For our optimizer, we will use SGD, and it will optimize the parameters of our model. For our loss, we wil use Negative Log Likelihood (together with the log_softmax of the last layer it is equivalent to the Cross Entropy while being more numerically stable).

# %%
optimizer = optim.SGD(model.parameters(), lr=0.1)
criterion = nn.NLLLoss()

# %% [markdown]
# We will define a custom metric to monitor during training.

# %%
def accuracy(preds, y):
    preds = preds.argmax(dim=1, keepdim=True) # get the index of the max log-probability
    correct = preds.eq(y.view_as(preds)).sum().item()
    return correct/preds.size(0)

# %% [markdown]
# Here, we do our training. At each step we do a forward pass of our input, we compute the gradients and we do an optimizer step. At the end of each epoch we also compute metrics with our validation dataset.

# %%
epochs = 10
for epoch in range(epochs):
    model.train()  # Train mode
    for i, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()  # Reset gradients from last step
        preds = model(x)  # Forward pass
        loss = criterion(preds, y)
        loss.backward()  # Compute gradients
        optimizer.step()  # Do an optimizer step
        if i%20 == 0:
            print(f"TRAIN Epoch {epoch}: [{i}/{len(train_loader)}] Loss: {loss.item():.4f}; Accuracy: {accuracy(preds, y)}")
        
    
    model.eval()  # Test mode
    for i, (x, y) in enumerate(test_loader):
        x, y = x.to(device), y.to(device)
        preds = model(x)
        loss = criterion(preds, y)
        if i%20 == 0:
            print(f"TEST Epoch {epoch}: [{i}/{len(test_loader)}] Loss: {loss.item():.4f}; Accuracy: {accuracy(preds, y)}")
# Out:
# TRAIN Epoch 0: [0/500] Loss: 1.1183; Accuracy: 0.56
# TRAIN Epoch 0: [20/500] Loss: 0.9881; Accuracy: 0.62
# TRAIN Epoch 0: [40/500] Loss: 1.0352; Accuracy: 0.6
# TRAIN Epoch 0: [60/500] Loss: 1.3214; Accuracy: 0.61
# TRAIN Epoch 0: [80/500] Loss: 1.3655; Accuracy: 0.42
# TRAIN Epoch 0: [100/500] Loss: 0.8846; Accuracy: 0.74
# TRAIN Epoch 0: [120/500] Loss: 1.1711; Accuracy: 0.58
# TRAIN Epoch 0: [140/500] Loss: 1.0779; Accuracy: 0.59
# TRAIN Epoch 0: [160/500] Loss: 0.9318; Accuracy: 0.69
# TRAIN Epoch 0: [180/500] Loss: 0.9817; Accuracy: 0.69
# TRAIN Epoch 0: [200/500] Loss: 1.0939; Accuracy: 0.57
# TRAIN Epoch 0: [220/500] Loss: 0.6934; Accuracy: 0.79
# TRAIN Epoch 0: [240/500] Loss: 1.0464; Accuracy: 0.66
# TRAIN Epoch 0: [260/500] Loss: 1.0419; Accuracy: 0.63
# TRAIN Epoch 0: [280/500] Loss: 0.8602; Accuracy: 0.74
# TRAIN Epoch 0: [300/500] Loss: 0.9258; Accuracy: 0.69
# TRAIN Epoch 0: [320/500] Loss: 1.1176; Accuracy: 0.64
# TRAIN Epoch 0: [340/500] Loss: 0.8646; Accuracy: 0.71
# TRAIN Epoch 0: [360/500] Loss: 0.8752; Accuracy: 0.7
# TRAIN Epoch 0: [380/500] Loss: 0.9153; Accuracy: 0.7
# TRAIN Epoch 0: [400/500] Loss: 0.9743; Accuracy: 0.66
# TRAIN Epoch 0: [420/500] Loss: 0.9993; Accuracy: 0.68
# TRAIN Epoch 0: [440/500] Loss: 0.8518; Accuracy: 0.73
# TRAIN Epoch 0: [460/500] Loss: 0.9276; Accuracy: 0.69
# TRAIN Epoch 0: [480/500] Loss: 1.1208; Accuracy: 0.59
# TEST Epoch 0: [0/100] Loss: 1.0300; Accuracy: 0.64
# TEST Epoch 0: [20/100] Loss: 0.9438; Accuracy: 0.66
# TEST Epoch 0: [40/100] Loss: 0.9391; Accuracy: 0.74
# TEST Epoch 0: [60/100] Loss: 1.0028; Accuracy: 0.62
# TEST Epoch 0: [80/100] Loss: 0.8910; Accuracy: 0.69
# TRAIN Epoch 1: [0/500] Loss: 0.8584; Accuracy: 0.73
# TRAIN Epoch 1: [20/500] Loss: 0.8817; Accuracy: 0.75
# TRAIN Epoch 1: [40/500] Loss: 0.7627; Accuracy: 0.77
# TRAIN Epoch 1: [60/500] Loss: 0.8307; Accuracy: 0.72
# TRAIN Epoch 1: [80/500] Loss: 0.7813; Accuracy: 0.79
# TRAIN Epoch 1: [100/500] Loss: 0.7422; Accuracy: 0.75
# TRAIN Epoch 1: [120/500] Loss: 0.8766; Accuracy: 0.67
# TRAIN Epoch 1: [140/500] Loss: 0.8700; Accuracy: 0.75
# TRAIN Epoch 1: [160/500] Loss: 0.8554; Accuracy: 0.74
# TRAIN Epoch 1: [180/500] Loss: 0.8433; Accuracy: 0.69
# TRAIN Epoch 1: [200/500] Loss: 0.7324; Accuracy: 0.71
# TRAIN Epoch 1: [220/500] Loss: 0.7724; Accuracy: 0.7
# TRAIN Epoch 1: [240/500] Loss: 0.8056; Accuracy: 0.73
# TRAIN Epoch 1: [260/500] Loss: 0.7277; Accuracy: 0.76
# TRAIN Epoch 1: [280/500] Loss: 0.7516; Accuracy: 0.75
# TRAIN Epoch 1: [300/500] Loss: 0.7192; Accuracy: 0.73
# TRAIN Epoch 1: [320/500] Loss: 0.9809; Accuracy: 0.64
# TRAIN Epoch 1: [340/500] Loss: 0.6926; Accuracy: 0.77
# TRAIN Epoch 1: [360/500] Loss: 0.9833; Accuracy: 0.68
# TRAIN Epoch 1: [380/500] Loss: 0.7735; Accuracy: 0.67
# TRAIN Epoch 1: [400/500] Loss: 0.9571; Accuracy: 0.66
# TRAIN Epoch 1: [420/500] Loss: 0.6522; Accuracy: 0.81
# TRAIN Epoch 1: [440/500] Loss: 0.8148; Accuracy: 0.7
# TRAIN Epoch 1: [460/500] Loss: 0.7746; Accuracy: 0.74
# TRAIN Epoch 1: [480/500] Loss: 0.8081; Accuracy: 0.71
# TEST Epoch 1: [0/100] Loss: 0.9424; Accuracy: 0.66
# TEST Epoch 1: [20/100] Loss: 0.8707; Accuracy: 0.64
# TEST Epoch 1: [40/100] Loss: 0.8083; Accuracy: 0.81
# TEST Epoch 1: [60/100] Loss: 0.9018; Accuracy: 0.68
# TEST Epoch 1: [80/100] Loss: 0.8146; Accuracy: 0.73
# TRAIN Epoch 2: [0/500] Loss: 0.5505; Accuracy: 0.83
# TRAIN Epoch 2: [20/500] Loss: 0.6129; Accuracy: 0.78
# TRAIN Epoch 2: [40/500] Loss: 0.9165; Accuracy: 0.72
# TRAIN Epoch 2: [60/500] Loss: 0.5272; Accuracy: 0.86
# TRAIN Epoch 2: [80/500] Loss: 0.7029; Accuracy: 0.79
# TRAIN Epoch 2: [100/500] Loss: 0.7956; Accuracy: 0.73
# TRAIN Epoch 2: [120/500] Loss: 0.6845; Accuracy: 0.7
# TRAIN Epoch 2: [140/500] Loss: 0.8735; Accuracy: 0.73
# TRAIN Epoch 2: [160/500] Loss: 0.6397; Accuracy: 0.8
# TRAIN Epoch 2: [180/500] Loss: 0.8842; Accuracy: 0.67
# TRAIN Epoch 2: [200/500] Loss: 0.7409; Accuracy: 0.68
# TRAIN Epoch 2: [220/500] Loss: 0.7446; Accuracy: 0.74
# TRAIN Epoch 2: [240/500] Loss: 0.6761; Accuracy: 0.74
# TRAIN Epoch 2: [260/500] Loss: 0.8803; Accuracy: 0.72
# TRAIN Epoch 2: [280/500] Loss: 0.6301; Accuracy: 0.8
# TRAIN Epoch 2: [300/500] Loss: 0.7426; Accuracy: 0.76
# TRAIN Epoch 2: [320/500] Loss: 0.7165; Accuracy: 0.73
# TRAIN Epoch 2: [340/500] Loss: 0.9283; Accuracy: 0.69
# TRAIN Epoch 2: [360/500] Loss: 0.7250; Accuracy: 0.71
# TRAIN Epoch 2: [380/500] Loss: 0.7877; Accuracy: 0.68
# TRAIN Epoch 2: [400/500] Loss: 0.8659; Accuracy: 0.69
# TRAIN Epoch 2: [420/500] Loss: 0.7721; Accuracy: 0.75
# TRAIN Epoch 2: [440/500] Loss: 0.6932; Accuracy: 0.74
# TRAIN Epoch 2: [460/500] Loss: 0.7890; Accuracy: 0.74
# TRAIN Epoch 2: [480/500] Loss: 0.8319; Accuracy: 0.69
# TEST Epoch 2: [0/100] Loss: 0.9957; Accuracy: 0.7
# TEST Epoch 2: [20/100] Loss: 0.9353; Accuracy: 0.68
# TEST Epoch 2: [40/100] Loss: 0.9110; Accuracy: 0.77
# TEST Epoch 2: [60/100] Loss: 0.8833; Accuracy: 0.69
# TEST Epoch 2: [80/100] Loss: 0.9074; Accuracy: 0.7
# TRAIN Epoch 3: [0/500] Loss: 0.5384; Accuracy: 0.82
# TRAIN Epoch 3: [20/500] Loss: 0.8585; Accuracy: 0.73
# TRAIN Epoch 3: [40/500] Loss: 0.3973; Accuracy: 0.84
# TRAIN Epoch 3: [60/500] Loss: 0.6738; Accuracy: 0.71
# TRAIN Epoch 3: [80/500] Loss: 0.5878; Accuracy: 0.77
# TRAIN Epoch 3: [100/500] Loss: 0.5353; Accuracy: 0.82
# TRAIN Epoch 3: [120/500] Loss: 0.5376; Accuracy: 0.8
# TRAIN Epoch 3: [140/500] Loss: 0.5481; Accuracy: 0.83
# TRAIN Epoch 3: [160/500] Loss: 0.5204; Accuracy: 0.82
# TRAIN Epoch 3: [180/500] Loss: 0.5844; Accuracy: 0.82
# TRAIN Epoch 3: [200/500] Loss: 0.7452; Accuracy: 0.84
# TRAIN Epoch 3: [220/500] Loss: 0.5677; Accuracy: 0.79
# TRAIN Epoch 3: [240/500] Loss: 0.6206; Accuracy: 0.76
# TRAIN Epoch 3: [260/500] Loss: 0.5913; Accuracy: 0.79
# TRAIN Epoch 3: [280/500] Loss: 0.6393; Accuracy: 0.8
# TRAIN Epoch 3: [300/500] Loss: 0.7253; Accuracy: 0.77
# TRAIN Epoch 3: [320/500] Loss: 0.7864; Accuracy: 0.73
# TRAIN Epoch 3: [340/500] Loss: 0.5587; Accuracy: 0.79
# TRAIN Epoch 3: [360/500] Loss: 0.8361; Accuracy: 0.7
# TRAIN Epoch 3: [380/500] Loss: 0.7658; Accuracy: 0.76
# TRAIN Epoch 3: [400/500] Loss: 0.5019; Accuracy: 0.82
# TRAIN Epoch 3: [420/500] Loss: 0.6362; Accuracy: 0.79
# TRAIN Epoch 3: [440/500] Loss: 0.5712; Accuracy: 0.83
# TRAIN Epoch 3: [460/500] Loss: 0.8208; Accuracy: 0.71
# TRAIN Epoch 3: [480/500] Loss: 0.8343; Accuracy: 0.73
# TEST Epoch 3: [0/100] Loss: 1.1093; Accuracy: 0.66
# TEST Epoch 3: [20/100] Loss: 0.8584; Accuracy: 0.7
# TEST Epoch 3: [40/100] Loss: 0.8745; Accuracy: 0.74
# TEST Epoch 3: [60/100] Loss: 0.8166; Accuracy: 0.74
# TEST Epoch 3: [80/100] Loss: 0.7991; Accuracy: 0.74
# TRAIN Epoch 4: [0/500] Loss: 0.4732; Accuracy: 0.84
# TRAIN Epoch 4: [20/500] Loss: 0.3413; Accuracy: 0.92
# TRAIN Epoch 4: [40/500] Loss: 0.4114; Accuracy: 0.88
# TRAIN Epoch 4: [60/500] Loss: 0.4481; Accuracy: 0.87
# TRAIN Epoch 4: [80/500] Loss: 0.6179; Accuracy: 0.8
# TRAIN Epoch 4: [100/500] Loss: 0.4400; Accuracy: 0.86
# TRAIN Epoch 4: [120/500] Loss: 0.3914; Accuracy: 0.86
# TRAIN Epoch 4: [140/500] Loss: 0.6033; Accuracy: 0.79
# TRAIN Epoch 4: [160/500] Loss: 0.6037; Accuracy: 0.77
# TRAIN Epoch 4: [180/500] Loss: 0.5971; Accuracy: 0.83
# TRAIN Epoch 4: [200/500] Loss: 0.7358; Accuracy: 0.75
# TRAIN Epoch 4: [220/500] Loss: 0.4996; Accuracy: 0.83
# TRAIN Epoch 4: [240/500] Loss: 0.5937; Accuracy: 0.78
# TRAIN Epoch 4: [260/500] Loss: 0.6428; Accuracy: 0.76
# TRAIN Epoch 4: [280/500] Loss: 0.4106; Accuracy: 0.86
# TRAIN Epoch 4: [300/500] Loss: 0.3983; Accuracy: 0.87
# TRAIN Epoch 4: [320/500] Loss: 0.4669; Accuracy: 0.83
# TRAIN Epoch 4: [340/500] Loss: 0.3654; Accuracy: 0.86
# TRAIN Epoch 4: [360/500] Loss: 0.5385; Accuracy: 0.82
# TRAIN Epoch 4: [380/500] Loss: 0.5907; Accuracy: 0.78
# TRAIN Epoch 4: [400/500] Loss: 0.5158; Accuracy: 0.86
# TRAIN Epoch 4: [420/500] Loss: 0.4617; Accuracy: 0.82
# TRAIN Epoch 4: [440/500] Loss: 0.5657; Accuracy: 0.78
# TRAIN Epoch 4: [460/500] Loss: 0.3297; Accuracy: 0.88
# TRAIN Epoch 4: [480/500] Loss: 0.5236; Accuracy: 0.77
# TEST Epoch 4: [0/100] Loss: 1.0837; Accuracy: 0.71
# TEST Epoch 4: [20/100] Loss: 1.0296; Accuracy: 0.61
# TEST Epoch 4: [40/100] Loss: 0.8677; Accuracy: 0.78
# TEST Epoch 4: [60/100] Loss: 0.9481; Accuracy: 0.7
# TEST Epoch 4: [80/100] Loss: 0.8410; Accuracy: 0.74
# TRAIN Epoch 5: [0/500] Loss: 0.3686; Accuracy: 0.85
# TRAIN Epoch 5: [20/500] Loss: 0.3841; Accuracy: 0.88
# TRAIN Epoch 5: [40/500] Loss: 0.3138; Accuracy: 0.88
# TRAIN Epoch 5: [60/500] Loss: 0.3302; Accuracy: 0.88
# TRAIN Epoch 5: [80/500] Loss: 0.2902; Accuracy: 0.93
# TRAIN Epoch 5: [100/500] Loss: 0.3279; Accuracy: 0.91
# TRAIN Epoch 5: [120/500] Loss: 0.3826; Accuracy: 0.89
# TRAIN Epoch 5: [140/500] Loss: 0.3121; Accuracy: 0.89
# TRAIN Epoch 5: [160/500] Loss: 0.2923; Accuracy: 0.89
# TRAIN Epoch 5: [180/500] Loss: 0.4135; Accuracy: 0.86
# TRAIN Epoch 5: [200/500] Loss: 0.4976; Accuracy: 0.85
# TRAIN Epoch 5: [220/500] Loss: 0.4439; Accuracy: 0.86
# TRAIN Epoch 5: [240/500] Loss: 0.3006; Accuracy: 0.9
# TRAIN Epoch 5: [260/500] Loss: 0.4112; Accuracy: 0.85
# TRAIN Epoch 5: [280/500] Loss: 0.3363; Accuracy: 0.87
# TRAIN Epoch 5: [300/500] Loss: 0.3851; Accuracy: 0.88
# TRAIN Epoch 5: [320/500] Loss: 0.4388; Accuracy: 0.85
# TRAIN Epoch 5: [340/500] Loss: 0.3866; Accuracy: 0.87
# TRAIN Epoch 5: [360/500] Loss: 0.4690; Accuracy: 0.81
# TRAIN Epoch 5: [380/500] Loss: 0.3930; Accuracy: 0.82
# TRAIN Epoch 5: [400/500] Loss: 0.2943; Accuracy: 0.88
# TRAIN Epoch 5: [420/500] Loss: 0.4782; Accuracy: 0.85
# TRAIN Epoch 5: [440/500] Loss: 0.4734; Accuracy: 0.85
# TRAIN Epoch 5: [460/500] Loss: 0.5463; Accuracy: 0.78
# TRAIN Epoch 5: [480/500] Loss: 0.5733; Accuracy: 0.81
# TEST Epoch 5: [0/100] Loss: 1.2648; Accuracy: 0.66
# TEST Epoch 5: [20/100] Loss: 1.0278; Accuracy: 0.63
# TEST Epoch 5: [40/100] Loss: 0.9115; Accuracy: 0.76
# TEST Epoch 5: [60/100] Loss: 0.8489; Accuracy: 0.7
# TEST Epoch 5: [80/100] Loss: 0.8688; Accuracy: 0.72
# TRAIN Epoch 6: [0/500] Loss: 0.2588; Accuracy: 0.92
# TRAIN Epoch 6: [20/500] Loss: 0.2008; Accuracy: 0.93
# TRAIN Epoch 6: [40/500] Loss: 0.2664; Accuracy: 0.9
# TRAIN Epoch 6: [60/500] Loss: 0.4002; Accuracy: 0.9
# TRAIN Epoch 6: [80/500] Loss: 0.3921; Accuracy: 0.86
# TRAIN Epoch 6: [100/500] Loss: 0.3266; Accuracy: 0.89
# TRAIN Epoch 6: [120/500] Loss: 0.4170; Accuracy: 0.85
# TRAIN Epoch 6: [140/500] Loss: 0.2675; Accuracy: 0.93
# TRAIN Epoch 6: [160/500] Loss: 0.2953; Accuracy: 0.92
# TRAIN Epoch 6: [180/500] Loss: 0.3199; Accuracy: 0.87
# TRAIN Epoch 6: [200/500] Loss: 0.3791; Accuracy: 0.85
# TRAIN Epoch 6: [220/500] Loss: 0.3325; Accuracy: 0.85
# TRAIN Epoch 6: [240/500] Loss: 0.3395; Accuracy: 0.87
# TRAIN Epoch 6: [260/500] Loss: 0.3177; Accuracy: 0.9
# TRAIN Epoch 6: [280/500] Loss: 0.2743; Accuracy: 0.91
# TRAIN Epoch 6: [300/500] Loss: 0.3609; Accuracy: 0.86
# TRAIN Epoch 6: [320/500] Loss: 0.4203; Accuracy: 0.86
# TRAIN Epoch 6: [340/500] Loss: 0.2970; Accuracy: 0.88
# TRAIN Epoch 6: [360/500] Loss: 0.4260; Accuracy: 0.85
# TRAIN Epoch 6: [380/500] Loss: 0.3875; Accuracy: 0.85
# TRAIN Epoch 6: [400/500] Loss: 0.4925; Accuracy: 0.85
# TRAIN Epoch 6: [420/500] Loss: 0.3126; Accuracy: 0.86
# TRAIN Epoch 6: [440/500] Loss: 0.3963; Accuracy: 0.85
# TRAIN Epoch 6: [460/500] Loss: 0.3298; Accuracy: 0.89
# TRAIN Epoch 6: [480/500] Loss: 0.5185; Accuracy: 0.83
# TEST Epoch 6: [0/100] Loss: 1.2091; Accuracy: 0.67
# TEST Epoch 6: [20/100] Loss: 1.1406; Accuracy: 0.63
# TEST Epoch 6: [40/100] Loss: 0.9628; Accuracy: 0.81
# TEST Epoch 6: [60/100] Loss: 0.9587; Accuracy: 0.72
# TEST Epoch 6: [80/100] Loss: 0.9238; Accuracy: 0.72
# TRAIN Epoch 7: [0/500] Loss: 0.2635; Accuracy: 0.91
# TRAIN Epoch 7: [20/500] Loss: 0.1323; Accuracy: 0.98
# TRAIN Epoch 7: [40/500] Loss: 0.1901; Accuracy: 0.95
# TRAIN Epoch 7: [60/500] Loss: 0.1317; Accuracy: 0.96
# TRAIN Epoch 7: [80/500] Loss: 0.3245; Accuracy: 0.93
# TRAIN Epoch 7: [100/500] Loss: 0.2513; Accuracy: 0.95
# TRAIN Epoch 7: [120/500] Loss: 0.2494; Accuracy: 0.91
# TRAIN Epoch 7: [140/500] Loss: 0.2499; Accuracy: 0.91
# TRAIN Epoch 7: [160/500] Loss: 0.1838; Accuracy: 0.94
# TRAIN Epoch 7: [180/500] Loss: 0.3319; Accuracy: 0.88
# TRAIN Epoch 7: [200/500] Loss: 0.2498; Accuracy: 0.93
# TRAIN Epoch 7: [220/500] Loss: 0.3877; Accuracy: 0.85
# TRAIN Epoch 7: [240/500] Loss: 0.1432; Accuracy: 0.97
# TRAIN Epoch 7: [260/500] Loss: 0.2094; Accuracy: 0.95
# TRAIN Epoch 7: [280/500] Loss: 0.2940; Accuracy: 0.89
# TRAIN Epoch 7: [300/500] Loss: 0.2383; Accuracy: 0.93
# TRAIN Epoch 7: [320/500] Loss: 0.4246; Accuracy: 0.88
# TRAIN Epoch 7: [340/500] Loss: 0.2391; Accuracy: 0.92
# TRAIN Epoch 7: [360/500] Loss: 0.1746; Accuracy: 0.96
# TRAIN Epoch 7: [380/500] Loss: 0.2540; Accuracy: 0.94
# TRAIN Epoch 7: [400/500] Loss: 0.3935; Accuracy: 0.89
# TRAIN Epoch 7: [420/500] Loss: 0.2996; Accuracy: 0.88
# TRAIN Epoch 7: [440/500] Loss: 0.2764; Accuracy: 0.89
# TRAIN Epoch 7: [460/500] Loss: 0.2920; Accuracy: 0.87
# TRAIN Epoch 7: [480/500] Loss: 0.3439; Accuracy: 0.88
# TEST Epoch 7: [0/100] Loss: 1.3971; Accuracy: 0.65
# TEST Epoch 7: [20/100] Loss: 1.1904; Accuracy: 0.63
# TEST Epoch 7: [40/100] Loss: 1.0666; Accuracy: 0.72
# TEST Epoch 7: [60/100] Loss: 0.9388; Accuracy: 0.74
# TEST Epoch 7: [80/100] Loss: 1.0248; Accuracy: 0.69
# TRAIN Epoch 8: [0/500] Loss: 0.2131; Accuracy: 0.9
# TRAIN Epoch 8: [20/500] Loss: 0.1279; Accuracy: 0.95
# TRAIN Epoch 8: [40/500] Loss: 0.1665; Accuracy: 0.94
# TRAIN Epoch 8: [60/500] Loss: 0.1041; Accuracy: 0.96
# TRAIN Epoch 8: [80/500] Loss: 0.1904; Accuracy: 0.92
# TRAIN Epoch 8: [100/500] Loss: 0.1048; Accuracy: 0.96
# TRAIN Epoch 8: [120/500] Loss: 0.2436; Accuracy: 0.91
# TRAIN Epoch 8: [140/500] Loss: 0.1135; Accuracy: 0.96
# TRAIN Epoch 8: [160/500] Loss: 0.1251; Accuracy: 0.96
# TRAIN Epoch 8: [180/500] Loss: 0.2080; Accuracy: 0.93
# TRAIN Epoch 8: [200/500] Loss: 0.2060; Accuracy: 0.94
# TRAIN Epoch 8: [220/500] Loss: 0.0939; Accuracy: 0.98
# TRAIN Epoch 8: [240/500] Loss: 0.1579; Accuracy: 0.95
# TRAIN Epoch 8: [260/500] Loss: 0.2661; Accuracy: 0.92
# TRAIN Epoch 8: [280/500] Loss: 0.2121; Accuracy: 0.91
# TRAIN Epoch 8: [300/500] Loss: 0.0974; Accuracy: 0.97
# TRAIN Epoch 8: [320/500] Loss: 0.2329; Accuracy: 0.91
# TRAIN Epoch 8: [340/500] Loss: 0.1999; Accuracy: 0.95
# TRAIN Epoch 8: [360/500] Loss: 0.2279; Accuracy: 0.94
# TRAIN Epoch 8: [380/500] Loss: 0.2359; Accuracy: 0.93
# TRAIN Epoch 8: [400/500] Loss: 0.1723; Accuracy: 0.95
# TRAIN Epoch 8: [420/500] Loss: 0.2910; Accuracy: 0.87
# TRAIN Epoch 8: [440/500] Loss: 0.1452; Accuracy: 0.95
# TRAIN Epoch 8: [460/500] Loss: 0.2429; Accuracy: 0.9
# TRAIN Epoch 8: [480/500] Loss: 0.1889; Accuracy: 0.94
# TEST Epoch 8: [0/100] Loss: 1.5289; Accuracy: 0.65
# TEST Epoch 8: [20/100] Loss: 1.7282; Accuracy: 0.61
# TEST Epoch 8: [40/100] Loss: 1.1911; Accuracy: 0.79
# TEST Epoch 8: [60/100] Loss: 1.1688; Accuracy: 0.68
# TEST Epoch 8: [80/100] Loss: 1.3376; Accuracy: 0.72
# TRAIN Epoch 9: [0/500] Loss: 0.2006; Accuracy: 0.92
# TRAIN Epoch 9: [20/500] Loss: 0.1159; Accuracy: 0.96
# TRAIN Epoch 9: [40/500] Loss: 0.1249; Accuracy: 0.96
# TRAIN Epoch 9: [60/500] Loss: 0.0717; Accuracy: 0.99
# TRAIN Epoch 9: [80/500] Loss: 0.1592; Accuracy: 0.93
# TRAIN Epoch 9: [100/500] Loss: 0.1192; Accuracy: 0.96
# TRAIN Epoch 9: [120/500] Loss: 0.1157; Accuracy: 0.95
# TRAIN Epoch 9: [140/500] Loss: 0.0508; Accuracy: 0.98
# TRAIN Epoch 9: [160/500] Loss: 0.1154; Accuracy: 0.96
# TRAIN Epoch 9: [180/500] Loss: 0.1281; Accuracy: 0.96
# TRAIN Epoch 9: [200/500] Loss: 0.1065; Accuracy: 0.97
# TRAIN Epoch 9: [220/500] Loss: 0.1943; Accuracy: 0.94
# TRAIN Epoch 9: [240/500] Loss: 0.3860; Accuracy: 0.86
# TRAIN Epoch 9: [260/500] Loss: 0.1889; Accuracy: 0.97
# TRAIN Epoch 9: [280/500] Loss: 0.1249; Accuracy: 0.98
# TRAIN Epoch 9: [300/500] Loss: 0.1444; Accuracy: 0.96
# TRAIN Epoch 9: [320/500] Loss: 0.1331; Accuracy: 0.94
# TRAIN Epoch 9: [340/500] Loss: 0.1235; Accuracy: 0.94
# TRAIN Epoch 9: [360/500] Loss: 0.1999; Accuracy: 0.95
# TRAIN Epoch 9: [380/500] Loss: 0.2022; Accuracy: 0.95
# TRAIN Epoch 9: [400/500] Loss: 0.2177; Accuracy: 0.92
# TRAIN Epoch 9: [420/500] Loss: 0.0869; Accuracy: 0.97
# TRAIN Epoch 9: [440/500] Loss: 0.1037; Accuracy: 0.97
# TRAIN Epoch 9: [460/500] Loss: 0.2086; Accuracy: 0.93
# TRAIN Epoch 9: [480/500] Loss: 0.3240; Accuracy: 0.9
# TEST Epoch 9: [0/100] Loss: 1.5950; Accuracy: 0.68
# TEST Epoch 9: [20/100] Loss: 1.7392; Accuracy: 0.62
# TEST Epoch 9: [40/100] Loss: 1.3535; Accuracy: 0.71
# TEST Epoch 9: [60/100] Loss: 1.0772; Accuracy: 0.75
# TEST Epoch 9: [80/100] Loss: 1.2469; Accuracy: 0.69

# %%
5*5*50
# Out:
# 1250

# %%
##   32*32
##   32 - 4  = 28    # no padding kernel 5, stride 1
##   28 / 2  = 14    # no padding kernel 5, stride 1
##   14 - 4  = 10    # no padding kernel 5, stride 1
##   10 / 2  = 5     # no padding kernel 5, stride 1

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=20, kernel_size=5, stride=1)
        self.conv2 = nn.Conv2d(in_channels=20, out_channels=50, kernel_size=5, stride=1)
        self.fc1 = nn.Linear(in_features=5*5*50, out_features=500)
        self.fc2 = nn.Linear(in_features=500, out_features=10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(x.size(0), -1)  # Flatten while keeping the batch dimension
        x = F.relu(self.fc1(x))
        x = F.log_softmax(self.fc2(x), dim=1)
        return x

# %%
model = Net().to(device)

# %%
train_dataset = datasets.CIFAR10("data/CIFAR10", train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),  # Here we could add extra data augmentation
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                   ]))
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=100, shuffle=True)

test_dataset = datasets.CIFAR10("data/CIFAR10", train=False, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                   ]))
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False)
# Out:
# 0it [00:00, ?it/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/CIFAR10/cifar-10-python.tar.gz
# 100%|█████████▉| 169975808/170498071 [00:33<00:00, 9525922.24it/s]
# Files already downloaded and verified

# %%
train_dataset

# %%
optimizer = optim.SGD(model.parameters(), lr=0.1)
criterion = nn.NLLLoss()

# %%
epochs = 3
for epoch in range(epochs):
    model.train()  # Train mode
    for i, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()  # Reset gradients from last step
        preds = model(x)  # Forward pass
        loss = criterion(preds, y)
        loss.backward()  # Compute gradients
        optimizer.step()  # Do an optimizer step
        if i%20 == 0:
            print(f"TRAIN Epoch {epoch}: [{i}/{len(train_loader)}] Loss: {loss.item():.4f}; Accuracy: {accuracy(preds, y)}")
        
    
    model.eval()  # Test mode
    for i, (x, y) in enumerate(test_loader):
        x, y = x.to(device), y.to(device)
        preds = model(x)
        loss = criterion(preds, y)
        if i%20 == 0:
            print(f"TEST Epoch {epoch}: [{i}/{len(test_loader)}] Loss: {loss.item():.4f}; Accuracy: {accuracy(preds, y)}")
# Out:
# TRAIN Epoch 0: [0/500] Loss: 2.3007; Accuracy: 0.05
# TRAIN Epoch 0: [20/500] Loss: 2.2784; Accuracy: 0.22
# TRAIN Epoch 0: [40/500] Loss: 2.1207; Accuracy: 0.24
# TRAIN Epoch 0: [60/500] Loss: 2.1040; Accuracy: 0.26
# TRAIN Epoch 0: [80/500] Loss: 2.0382; Accuracy: 0.27
# TRAIN Epoch 0: [100/500] Loss: 1.9729; Accuracy: 0.27
# TRAIN Epoch 0: [120/500] Loss: 1.9218; Accuracy: 0.34
# TRAIN Epoch 0: [140/500] Loss: 1.7837; Accuracy: 0.34
# TRAIN Epoch 0: [160/500] Loss: 1.9058; Accuracy: 0.26
# TRAIN Epoch 0: [180/500] Loss: 1.7861; Accuracy: 0.32
# TRAIN Epoch 0: [200/500] Loss: 1.7969; Accuracy: 0.29
# TRAIN Epoch 0: [220/500] Loss: 1.6589; Accuracy: 0.47
# TRAIN Epoch 0: [240/500] Loss: 1.5434; Accuracy: 0.43
# TRAIN Epoch 0: [260/500] Loss: 1.5481; Accuracy: 0.48
# TRAIN Epoch 0: [280/500] Loss: 1.7799; Accuracy: 0.33
# TRAIN Epoch 0: [300/500] Loss: 1.7060; Accuracy: 0.38
# TRAIN Epoch 0: [320/500] Loss: 1.6001; Accuracy: 0.34
# TRAIN Epoch 0: [340/500] Loss: 1.6437; Accuracy: 0.39
# TRAIN Epoch 0: [360/500] Loss: 1.7260; Accuracy: 0.4
# TRAIN Epoch 0: [380/500] Loss: 1.7075; Accuracy: 0.47
# TRAIN Epoch 0: [400/500] Loss: 1.4385; Accuracy: 0.55
# TRAIN Epoch 0: [420/500] Loss: 1.5315; Accuracy: 0.4
# TRAIN Epoch 0: [440/500] Loss: 1.5198; Accuracy: 0.42
# TRAIN Epoch 0: [460/500] Loss: 1.2651; Accuracy: 0.58
# TRAIN Epoch 0: [480/500] Loss: 1.5291; Accuracy: 0.42
# TEST Epoch 0: [0/100] Loss: 1.3856; Accuracy: 0.48
# TEST Epoch 0: [20/100] Loss: 1.3212; Accuracy: 0.59
# TEST Epoch 0: [40/100] Loss: 1.3480; Accuracy: 0.48
# TEST Epoch 0: [60/100] Loss: 1.4412; Accuracy: 0.43
# TEST Epoch 0: [80/100] Loss: 1.3966; Accuracy: 0.51
# TRAIN Epoch 1: [0/500] Loss: 1.5575; Accuracy: 0.41
# TRAIN Epoch 1: [20/500] Loss: 1.5681; Accuracy: 0.43
# TRAIN Epoch 1: [40/500] Loss: 1.5778; Accuracy: 0.45
# TRAIN Epoch 1: [60/500] Loss: 1.3599; Accuracy: 0.54
# TRAIN Epoch 1: [80/500] Loss: 1.3202; Accuracy: 0.5
# TRAIN Epoch 1: [100/500] Loss: 1.6053; Accuracy: 0.43
# TRAIN Epoch 1: [120/500] Loss: 1.2885; Accuracy: 0.53
# TRAIN Epoch 1: [140/500] Loss: 1.4030; Accuracy: 0.52
# TRAIN Epoch 1: [160/500] Loss: 1.4615; Accuracy: 0.52
# TRAIN Epoch 1: [180/500] Loss: 1.3084; Accuracy: 0.51
# TRAIN Epoch 1: [200/500] Loss: 1.3102; Accuracy: 0.52
# TRAIN Epoch 1: [220/500] Loss: 1.1924; Accuracy: 0.53
# TRAIN Epoch 1: [240/500] Loss: 1.2345; Accuracy: 0.53
# TRAIN Epoch 1: [260/500] Loss: 1.3160; Accuracy: 0.57
# TRAIN Epoch 1: [280/500] Loss: 1.2712; Accuracy: 0.54
# TRAIN Epoch 1: [300/500] Loss: 1.3873; Accuracy: 0.55
# TRAIN Epoch 1: [320/500] Loss: 1.2349; Accuracy: 0.55
# TRAIN Epoch 1: [340/500] Loss: 1.3642; Accuracy: 0.55
# TRAIN Epoch 1: [360/500] Loss: 1.3370; Accuracy: 0.53
# TRAIN Epoch 1: [380/500] Loss: 1.3770; Accuracy: 0.53
# TRAIN Epoch 1: [400/500] Loss: 1.1471; Accuracy: 0.56
# TRAIN Epoch 1: [420/500] Loss: 1.2513; Accuracy: 0.53
# TRAIN Epoch 1: [440/500] Loss: 1.2441; Accuracy: 0.55
# TRAIN Epoch 1: [460/500] Loss: 1.2009; Accuracy: 0.58
# TRAIN Epoch 1: [480/500] Loss: 1.0322; Accuracy: 0.68
# TEST Epoch 1: [0/100] Loss: 1.0649; Accuracy: 0.68
# TEST Epoch 1: [20/100] Loss: 1.1049; Accuracy: 0.61
# TEST Epoch 1: [40/100] Loss: 1.1805; Accuracy: 0.61
# TEST Epoch 1: [60/100] Loss: 1.1900; Accuracy: 0.54
# TEST Epoch 1: [80/100] Loss: 1.2127; Accuracy: 0.59
# TRAIN Epoch 2: [0/500] Loss: 1.2033; Accuracy: 0.59
# TRAIN Epoch 2: [20/500] Loss: 1.2790; Accuracy: 0.61
# TRAIN Epoch 2: [40/500] Loss: 1.1751; Accuracy: 0.56
# TRAIN Epoch 2: [60/500] Loss: 1.3151; Accuracy: 0.53
# TRAIN Epoch 2: [80/500] Loss: 1.3780; Accuracy: 0.55
# TRAIN Epoch 2: [100/500] Loss: 1.1814; Accuracy: 0.53
# TRAIN Epoch 2: [120/500] Loss: 1.1366; Accuracy: 0.63
# TRAIN Epoch 2: [140/500] Loss: 1.2085; Accuracy: 0.66
# TRAIN Epoch 2: [160/500] Loss: 1.1629; Accuracy: 0.59
# TRAIN Epoch 2: [180/500] Loss: 1.3728; Accuracy: 0.52
# TRAIN Epoch 2: [200/500] Loss: 1.1253; Accuracy: 0.64
# TRAIN Epoch 2: [220/500] Loss: 0.9785; Accuracy: 0.66
# TRAIN Epoch 2: [240/500] Loss: 1.1074; Accuracy: 0.61
# TRAIN Epoch 2: [260/500] Loss: 1.0405; Accuracy: 0.63
# TRAIN Epoch 2: [280/500] Loss: 1.1980; Accuracy: 0.57
# TRAIN Epoch 2: [300/500] Loss: 0.9824; Accuracy: 0.61
# TRAIN Epoch 2: [320/500] Loss: 0.9845; Accuracy: 0.66
# TRAIN Epoch 2: [340/500] Loss: 0.9162; Accuracy: 0.71
# TRAIN Epoch 2: [360/500] Loss: 0.9893; Accuracy: 0.64
# TRAIN Epoch 2: [380/500] Loss: 1.0373; Accuracy: 0.63
# TRAIN Epoch 2: [400/500] Loss: 1.1029; Accuracy: 0.6
# TRAIN Epoch 2: [420/500] Loss: 1.2562; Accuracy: 0.51
# TRAIN Epoch 2: [440/500] Loss: 1.1033; Accuracy: 0.6
# TRAIN Epoch 2: [460/500] Loss: 1.1550; Accuracy: 0.59
# TRAIN Epoch 2: [480/500] Loss: 0.9516; Accuracy: 0.64
# TEST Epoch 2: [0/100] Loss: 1.1266; Accuracy: 0.66
# TEST Epoch 2: [20/100] Loss: 0.9844; Accuracy: 0.64
# TEST Epoch 2: [40/100] Loss: 1.1528; Accuracy: 0.64
# TEST Epoch 2: [60/100] Loss: 1.0972; Accuracy: 0.55
# TEST Epoch 2: [80/100] Loss: 1.0976; Accuracy: 0.64

# %%
imshow(train_dataset.data[0])

# %%
imshow(train_dataset.data[1])

# %% [markdown]
# ## Exercice 1: train with CIFAR10
#
# You should complete the following code to train a network with CIFAR10.
#
# If you want, you can try to add data augmentation, dropout and weight decay to regularize the model.

# %% [markdown]
# # Pretrained imagenet models

# %% [markdown]
# In both PyTorch and Keras there are many models pretrained with Imagenet. You can see the lists here: https://pytorch.org/docs/stable/torchvision/models.html
# and https://keras.io/applications/.
# We will see how to use a pretrained VGG16 from PyTorch to predict images taken from the internet.

# %% [markdown]
# We first declare our model with `pretrained=True`, which will download the pretrained weights.

# %%
import torchvision.models as models

model = models.alexnet(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.torch/models/alexnet-owt-4df8aa71.pth
#
# 0it [00:00, ?it/s]
# 3670016it [00:00, 35563745.81it/s]
# 9895936it [00:00, 40786933.25it/s]
# 15818752it [00:00, 44952362.34it/s]
# 19423232it [00:00, 39574036.63it/s]
# 26951680it [00:00, 46132878.27it/s]
# 31621120it [00:00, 44310315.85it/s]
# 36110336it [00:00, 34253147.69it/s]
# 41377792it [00:00, 38266475.05it/s]
# 48226304it [00:01, 44003687.91it/s]
# 53231616it [00:01, 33615139.19it/s]
# 57794560it [00:01, 36463293.21it/s]
# 64397312it [00:01, 42119998.09it/s]
# 71884800it [00:01, 48475923.96it/s]
# 77611008it [00:01, 48622726.54it/s]
# 83091456it [00:01, 41153534.82it/s]
# 89169920it [00:01, 45566467.79it/s]
# 94314496it [00:02, 42610023.22it/s]
# 100777984it [00:02, 45316766.01it/s]
# 108363776it [00:02, 51536885.34it/s]
# 114065408it [00:02, 51474038.48it/s]
# 119603200it [00:02, 47300947.57it/s]
# 124829696it [00:02, 48260188.96it/s]
# 129900544it [00:02, 48804521.67it/s]
# 137158656it [00:02, 54120317.11it/s]
# 142876672it [00:03, 51037765.24it/s]
# 148226048it [00:03, 51728125.56it/s]
# 153575424it [00:03, 51684113.76it/s]
# 159825920it [00:03, 54512682.61it/s]
# 166813696it [00:03, 58358641.98it/s]
# 173899776it [00:03, 59175605.93it/s]
# 179937280it [00:03, 52389179.19it/s]
# 187211776it [00:03, 57184000.44it/s]
# 194150400it [00:03, 60284019.75it/s]
# 200433664it [00:03, 59185073.73it/s]
# 206602240it [00:04, 55799016.11it/s]
# 213221376it [00:04, 58545741.79it/s]
# 219234304it [00:04, 57071499.10it/s]
# 225058816it [00:04, 50496429.09it/s]
# 230334464it [00:04, 46701059.85it/s]
# 237617152it [00:04, 52330004.53it/s]
# 244277248it [00:04, 55917201.29it/s]
# 244418560it [00:04, 50817949.66it/s]

# %% [markdown]
# We also load the 1000 imagenet labels in a Python dictionary.

# %%
import json
import ast
import urllib
urllib.request.urlretrieve("https://gist.githubusercontent.com/yrevar/942d3a0ac09ec9e5eb3a/raw/238f720ff059c1f82f368259d1ca4ffa5dd8f9f5/imagenet1000_clsidx_to_labels.txt", "labels.json")
with open("labels.json") as f:
    labels = ast.literal_eval(f.read())
print(labels)
# Out:
# {0: 'tench, Tinca tinca', 1: 'goldfish, Carassius auratus', 2: 'great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias', 3: 'tiger shark, Galeocerdo cuvieri', 4: 'hammerhead, hammerhead shark', 5: 'electric ray, crampfish, numbfish, torpedo', 6: 'stingray', 7: 'cock', 8: 'hen', 9: 'ostrich, Struthio camelus', 10: 'brambling, Fringilla montifringilla', 11: 'goldfinch, Carduelis carduelis', 12: 'house finch, linnet, Carpodacus mexicanus', 13: 'junco, snowbird', 14: 'indigo bunting, indigo finch, indigo bird, Passerina cyanea', 15: 'robin, American robin, Turdus migratorius', 16: 'bulbul', 17: 'jay', 18: 'magpie', 19: 'chickadee', 20: 'water ouzel, dipper', 21: 'kite', 22: 'bald eagle, American eagle, Haliaeetus leucocephalus', 23: 'vulture', 24: 'great grey owl, great gray owl, Strix nebulosa', 25: 'European fire salamander, Salamandra salamandra', 26: 'common newt, Triturus vulgaris', 27: 'eft', 28: 'spotted salamander, Ambystoma maculatum', 29: 'axolotl, mud puppy, Ambystoma mexicanum', 30: 'bullfrog, Rana catesbeiana', 31: 'tree frog, tree-frog', 32: 'tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui', 33: 'loggerhead, loggerhead turtle, Caretta caretta', 34: 'leatherback turtle, leatherback, leathery turtle, Dermochelys coriacea', 35: 'mud turtle', 36: 'terrapin', 37: 'box turtle, box tortoise', 38: 'banded gecko', 39: 'common iguana, iguana, Iguana iguana', 40: 'American chameleon, anole, Anolis carolinensis', 41: 'whiptail, whiptail lizard', 42: 'agama', 43: 'frilled lizard, Chlamydosaurus kingi', 44: 'alligator lizard', 45: 'Gila monster, Heloderma suspectum', 46: 'green lizard, Lacerta viridis', 47: 'African chameleon, Chamaeleo chamaeleon', 48: 'Komodo dragon, Komodo lizard, dragon lizard, giant lizard, Varanus komodoensis', 49: 'African crocodile, Nile crocodile, Crocodylus niloticus', 50: 'American alligator, Alligator mississipiensis', 51: 'triceratops', 52: 'thunder snake, worm snake, Carphophis amoenus', 53: 'ringneck snake, ring-necked snake, ring snake', 54: 'hognose snake, puff adder, sand viper', 55: 'green snake, grass snake', 56: 'king snake, kingsnake', 57: 'garter snake, grass snake', 58: 'water snake', 59: 'vine snake', 60: 'night snake, Hypsiglena torquata', 61: 'boa constrictor, Constrictor constrictor', 62: 'rock python, rock snake, Python sebae', 63: 'Indian cobra, Naja naja', 64: 'green mamba', 65: 'sea snake', 66: 'horned viper, cerastes, sand viper, horned asp, Cerastes cornutus', 67: 'diamondback, diamondback rattlesnake, Crotalus adamanteus', 68: 'sidewinder, horned rattlesnake, Crotalus cerastes', 69: 'trilobite', 70: 'harvestman, daddy longlegs, Phalangium opilio', 71: 'scorpion', 72: 'black and gold garden spider, Argiope aurantia', 73: 'barn spider, Araneus cavaticus', 74: 'garden spider, Aranea diademata', 75: 'black widow, Latrodectus mactans', 76: 'tarantula', 77: 'wolf spider, hunting spider', 78: 'tick', 79: 'centipede', 80: 'black grouse', 81: 'ptarmigan', 82: 'ruffed grouse, partridge, Bonasa umbellus', 83: 'prairie chicken, prairie grouse, prairie fowl', 84: 'peacock', 85: 'quail', 86: 'partridge', 87: 'African grey, African gray, Psittacus erithacus', 88: 'macaw', 89: 'sulphur-crested cockatoo, Kakatoe galerita, Cacatua galerita', 90: 'lorikeet', 91: 'coucal', 92: 'bee eater', 93: 'hornbill', 94: 'hummingbird', 95: 'jacamar', 96: 'toucan', 97: 'drake', 98: 'red-breasted merganser, Mergus serrator', 99: 'goose', 100: 'black swan, Cygnus atratus', 101: 'tusker', 102: 'echidna, spiny anteater, anteater', 103: 'platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus', 104: 'wallaby, brush kangaroo', 105: 'koala, koala bear, kangaroo bear, native bear, Phascolarctos cinereus', 106: 'wombat', 107: 'jellyfish', 108: 'sea anemone, anemone', 109: 'brain coral', 110: 'flatworm, platyhelminth', 111: 'nematode, nematode worm, roundworm', 112: 'conch', 113: 'snail', 114: 'slug', 115: 'sea slug, nudibranch', 116: 'chiton, co ...

# %% [markdown]
# We can now download a sample image to test our network.

# %%
import urllib
from PIL import Image
urllib.request.urlretrieve("https://3c1703fe8d.site.internapcdn.net/newman/gfx/news/hires/2018/2-dog.jpg", "image.jpg")
# %ls
pil_image = Image.open("image.jpg")
imshow(np.asarray(pil_image))
# Out:
# data/  image.jpg  labels.json  sample_data/

# %% [markdown]
# We should do some preprocessing before feeding the image to our network. The following transformations are the same that were used when training with Imagenet. Note that we have to add a batch dimension at the beginning, even if we are feeding just one image to the network.

# %%
preprocess = transforms.Compose([transforms.Resize(256), transforms.CenterCrop(224), transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])
torch_image = preprocess(pil_image)
torch_image = torch_image.unsqueeze(0)  # Add batch dimension
print("Image shape: ", torch_image.shape)
print("Image values: ", torch_image)
# Out:
# Image shape:  torch.Size([1, 3, 224, 224])
# Image values:  tensor([[[[-1.0733, -1.0562, -1.0048,  ...,  0.2453,  0.2967,  0.2967],
#           [-1.0562, -1.0390, -1.0048,  ...,  0.1939,  0.2453,  0.2624],
#           [-1.0219, -0.9877, -0.9534,  ...,  0.1597,  0.2111,  0.2453],
#           ...,
#           [-1.4843, -1.4843, -1.4672,  ...,  1.8208,  1.8893,  1.9064],
#           [-1.4843, -1.4843, -1.4672,  ...,  1.8550,  1.8722,  1.9235],
#           [-1.4843, -1.4843, -1.4672,  ...,  1.8379,  1.8893,  1.9407]],
#
#          [[-0.8102, -0.7752, -0.7402,  ...,  0.4853,  0.5203,  0.5378],
#           [-0.7752, -0.7577, -0.7227,  ...,  0.4503,  0.4853,  0.5203],
#           [-0.7577, -0.7227, -0.7052,  ...,  0.4153,  0.4678,  0.5028],
#           ...,
#           [-1.1779, -1.1779, -1.1779,  ...,  0.9755,  1.0805,  1.2031],
#           [-1.1779, -1.1954, -1.1779,  ...,  1.0105,  1.0630,  1.2031],
#           [-1.1779, -1.1779, -1.1779,  ...,  1.0280,  1.1155,  1.2381]],
#
#          [[-1.6127, -1.5953, -1.5604,  ..., -0.3055, -0.2707, -0.2532],
#           [-1.5779, -1.5779, -1.5604,  ..., -0.2881, -0.2358, -0.2358],
#           [-1.5604, -1.5604, -1.5256,  ..., -0.2881, -0.2358, -0.2010],
#           ...,
#           [-1.6476, -1.6476, -1.6476,  ...,  0.3393,  0.4962,  0.6356],
#           [-1.6476, -1.6650, -1.6476,  ...,  0.3916,  0.4439,  0.6182],
#           [-1.6650, -1.6650, -1.6476,  ...,  0.4265,  0.5311,  0.7054]]]])

# %% [markdown]
# Now we can get the predictions of our network. Note that a network trained with imagenet will have 1000 outputs. Here we only show the top 3 predictions and their probabilities.

# %%
output = model(torch_image)
print("Output shape: ", output.shape)
probs, idxs = output.topk(3)
print(probs[0])
print([labels[idx.item()] for idx in idxs[0]])
# Out:
# Output shape:  torch.Size([1, 1000])
# tensor([17.4735, 16.8788, 15.2227], grad_fn=<SelectBackward>)
# ['Labrador retriever', 'golden retriever', 'Staffordshire bullterrier, Staffordshire bull terrier']

# %% [markdown]
# # Exercice 2
# Do the prediction with other images using different networks and compare the results.  You can use the function following function predict_from_url. The list of pretrained PyTorch networks can be found here https://pytorch.org/docs/stable/torchvision/models.html

# %%
def predict_from_url(url, model):
    urllib.request.urlretrieve(url, "image.jpg")
    pil_image = Image.open("image.jpg")
    imshow(np.asarray(pil_image))
    torch_image = preprocess(pil_image).unsqueeze(0)
    output = model(torch_image)
    probs, idxs = output.topk(3)
    print(probs[0])
    print([labels[idx.item()] for idx in idxs[0]])

predict_from_url("https://images.tienda.com/is/image/LaTienda/mixed-seafood-paella?&wid=414&qlt=60", model)
# Out:
# tensor([11.9918, 11.6718, 11.2402], grad_fn=<SelectBackward>)
# ['hot pot, hotpot', 'pizza, pizza pie', 'potpie']

# %%
https://images.tienda.com/is/image/LaTienda/mixed-seafood-paella?&wid=414&qlt=60
